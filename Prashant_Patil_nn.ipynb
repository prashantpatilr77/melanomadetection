# %% [markdown]
# Problem statement: To build a CNN based model which can accurately detect melanoma. Melanoma is a type of cancer that can be deadly if not detected early. It accounts for 75% of skin cancer deaths. A solution which can evaluate images and alert the dermatologists about the presence of melanoma has the potential to reduce a lot of manual effort needed in diagnosis.

# %% [markdown]
# ### Importing Skin Cancer Data
# #### To do: Take necessary actions to read the data

# %% [markdown]
# ### Importing all the important libraries

# %%
import pathlib
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
import PIL
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten, BatchNormalization, Conv2D, MaxPooling2D

# %%
## If you are using the data by mounting the google drive, use the following :
## from google.colab import drive
## drive.mount('/content/gdrive')

##Ref:https://towardsdatascience.com/downloading-datasets-into-google-drive-via-google-colab-bcb1b30b0166

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# This assignment uses a dataset of about 2357 images of skin cancer types. The dataset contains 9 sub-directories in each train and test subdirectories. The 9 sub-directories contains the images of 9 skin cancer types respectively.

# %%
# Defining the path for train and test images
## Todo: Update the paths of the train and test dataset
data_dir_train = pathlib.Path("/content/gdrive/MyDrive/AIML/Skincancerimglib/Train")
data_dir_test = pathlib.Path("/content/gdrive/MyDrive/AIML/Skincancerimglib/Test")

# %%
image_count_train = len(list(data_dir_train.glob('*/*.jpg')))
print(image_count_train)
image_count_test = len(list(data_dir_test.glob('*/*.jpg')))
print(image_count_test)
# Out:
# 2259
# 118

# %% [markdown]
# ### Load using keras.preprocessing
#
# Let's load these images off disk using the helpful image_dataset_from_directory utility.

# %% [markdown]
# ### Create a dataset
#
# Define some parameters for the loader:

# %%
batch_size = 32
img_height = 180
img_width = 180
num_classes = 9

# %% [markdown]
# Use 80% of the images for training, and 20% for validation.

# %%
## Write your train dataset here
## Note use seed=123 while creating your dataset using tf.keras.preprocessing.image_dataset_from_directory
## Note, make sure your resize your images to the size img_height*img_width, while writting the dataset
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    data_dir_train,
    seed=123,
    validation_split= 0.2,
    subset= 'training',
    image_size=(img_height,img_width),
    batch_size = batch_size
)
# Out:
# Found 2259 files belonging to 9 classes.
# Using 1808 files for training.

# %%
## Write your validation dataset here
## Note use seed=123 while creating your dataset using tf.keras.preprocessing.image_dataset_from_directory
## Note, make sure your resize your images to the size img_height*img_width, while writting the dataset
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
    data_dir_train,
    seed=123,
    validation_split= 0.2,
    subset= 'validation',
    image_size=(img_height,img_width),
    batch_size = batch_size
)
# Out:
# Found 2259 files belonging to 9 classes.
# Using 451 files for validation.

# %%
# List out all the classes of skin cancer and store them in a list. 
# You can find the class names in the class_names attribute on these datasets. 
# These correspond to the directory names in alphabetical order.
class_names = train_ds.class_names
print(class_names)
# Out:
# ['actinic keratosis', 'basal cell carcinoma', 'dermatofibroma', 'melanoma', 'nevus', 'pigmented benign keratosis', 'seborrheic keratosis', 'squamous cell carcinoma', 'vascular lesion']

# %% [markdown]
# ### Visualize the data
# #### Todo, create a code to visualize one instance of all the nine classes present in the dataset

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(20,20))
for i in range(9): 
  plt.subplot(3, 3, i + 1)
  image = plt.imread(str(list(data_dir_train.glob(class_names[i]+'/*.jpg'))[0]))
  plt.title(class_names[i])
  plt.imshow(image)
  plt.axis("off")
### your code goes here, you can use training or validation data to visualize

# %% [markdown]
# The `image_batch` is a tensor of the shape `(32, 180, 180, 3)`. This is a batch of 32 images of shape `180x180x3` (the last dimension refers to color channels RGB). The `label_batch` is a tensor of the shape `(32,)`, these are corresponding labels to the 32 images.

# %% [markdown]
# `Dataset.cache()` keeps the images in memory after they're loaded off disk during the first epoch.
#
# `Dataset.prefetch()` overlaps data preprocessing and model execution while training.

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# ### Create the model
# #### Todo: Create a CNN model, which can accurately detect 9 classes present in the dataset. Use ```layers.experimental.preprocessing.Rescaling``` to normalize pixel values between (0,1). The RGB channel values are in the `[0, 255]` range. This is not ideal for a neural network. Here, it is good to standardize values to be in the `[0, 1]`

# %%
### Your code goes here
from keras.layers import MaxPool2D
model = Sequential([
                    layers.experimental.preprocessing.Rescaling(1./255, input_shape=(img_height, img_width,3))
])
model.add(Conv2D(filters = 32, kernel_size = (3,3),padding = 'Same', 
                 activation ='relu', input_shape = (180, 180, 32)))

model.add(Conv2D(filters = 32, kernel_size = (3,3),padding = 'Same', 
                 activation ='relu'))

model.add(MaxPool2D(pool_size=(2,2)))

model.add(Conv2D(filters = 32, kernel_size = (3,3),padding = 'Same', 
                 activation ='relu'))

model.add(MaxPool2D(pool_size=(2,2)))

model.add(Conv2D(filters = 64, kernel_size = (3,3),padding = 'Same', 
                 activation ='relu'))

model.add(MaxPool2D(pool_size=(2,2)))

model.add(Conv2D(filters = 64, kernel_size = (3,3),padding = 'Same', 
                 activation ='relu'))

model.add(MaxPool2D(pool_size=(2,2)))

model.add(Dropout(0.25))

model.add(Flatten())

model.add(Dense(num_classes, activation = "softmax"))

# %% [markdown]
# ### Compile the model
# Choose an appropirate optimiser and loss function for model training

# %%
### Todo, choose an appropirate optimiser and loss function
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
# View the summary of all layers
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling_1 (Rescaling)     (None, 180, 180, 3)       0
#
#  conv2d_5 (Conv2D)           (None, 180, 180, 32)      896
#
#  conv2d_6 (Conv2D)           (None, 180, 180, 32)      9248
#
#  max_pooling2d_4 (MaxPooling  (None, 90, 90, 32)       0
#  2D)
#
#  conv2d_7 (Conv2D)           (None, 90, 90, 32)        9248
#
#  max_pooling2d_5 (MaxPooling  (None, 45, 45, 32)       0
#  2D)
#
#  conv2d_8 (Conv2D)           (None, 45, 45, 64)        18496
#
#  max_pooling2d_6 (MaxPooling  (None, 22, 22, 64)       0
#  2D)
#
#  conv2d_9 (Conv2D)           (None, 22, 22, 64)        36928
#
#  max_pooling2d_7 (MaxPooling  (None, 11, 11, 64)       0
#  2D)
#
#  dropout_1 (Dropout)         (None, 11, 11, 64)        0
#
#  flatten_1 (Flatten)         (None, 7744)              0
#
#  dense_1 (Dense)             (None, 9)                 69705
#
# =================================================================
# Total params: 144,521
# Trainable params: 144,521
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Train the model

# %%
epochs = 30
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/30
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:1082: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a sigmoid or softmax activation and thus does not represent logits. Was this intended?"
#   return dispatch_target(*args, **kwargs)
# 57/57 [==============================] - 57s 1s/step - loss: 2.0300 - accuracy: 0.2096 - val_loss: 1.9893 - val_accuracy: 0.2439
# Epoch 2/30
# 57/57 [==============================] - 7s 126ms/step - loss: 1.8316 - accuracy: 0.3335 - val_loss: 1.8205 - val_accuracy: 0.2971
# Epoch 3/30
# 57/57 [==============================] - 7s 125ms/step - loss: 1.6697 - accuracy: 0.3894 - val_loss: 1.7011 - val_accuracy: 0.4013
# Epoch 4/30
# 57/57 [==============================] - 7s 124ms/step - loss: 1.5833 - accuracy: 0.4165 - val_loss: 1.6059 - val_accuracy: 0.4191
# Epoch 5/30
# 57/57 [==============================] - 7s 124ms/step - loss: 1.4974 - accuracy: 0.4746 - val_loss: 1.6131 - val_accuracy: 0.4191
# Epoch 6/30
# 57/57 [==============================] - 7s 124ms/step - loss: 1.4429 - accuracy: 0.5066 - val_loss: 1.4764 - val_accuracy: 0.4701
# Epoch 7/30
# 57/57 [==============================] - 7s 125ms/step - loss: 1.3751 - accuracy: 0.5304 - val_loss: 1.6393 - val_accuracy: 0.4169
# Epoch 8/30
# 57/57 [==============================] - 7s 124ms/step - loss: 1.4347 - accuracy: 0.5050 - val_loss: 1.4628 - val_accuracy: 0.4834
# Epoch 9/30
# 57/57 [==============================] - 7s 124ms/step - loss: 1.3103 - accuracy: 0.5481 - val_loss: 1.3832 - val_accuracy: 0.5188
# Epoch 10/30
# 57/57 [==============================] - 7s 123ms/step - loss: 1.2850 - accuracy: 0.5586 - val_loss: 1.3712 - val_accuracy: 0.5011
# Epoch 11/30
# 57/57 [==============================] - 7s 123ms/step - loss: 1.2095 - accuracy: 0.5708 - val_loss: 1.3881 - val_accuracy: 0.5100
# Epoch 12/30
# 57/57 [==============================] - 7s 123ms/step - loss: 1.1914 - accuracy: 0.5785 - val_loss: 1.3839 - val_accuracy: 0.5233
# Epoch 13/30
# 57/57 [==============================] - 7s 125ms/step - loss: 1.1252 - accuracy: 0.6090 - val_loss: 1.5357 - val_accuracy: 0.4789
# Epoch 14/30
# 57/57 [==============================] - 7s 124ms/step - loss: 1.0930 - accuracy: 0.6073 - val_loss: 1.4211 - val_accuracy: 0.5233
# Epoch 15/30
# 57/57 [==============================] - 7s 124ms/step - loss: 1.0731 - accuracy: 0.6283 - val_loss: 1.3875 - val_accuracy: 0.5410
# Epoch 16/30
# 57/57 [==============================] - 7s 123ms/step - loss: 1.0192 - accuracy: 0.6338 - val_loss: 1.6254 - val_accuracy: 0.4812
# Epoch 17/30
# 57/57 [==============================] - 7s 124ms/step - loss: 0.9391 - accuracy: 0.6576 - val_loss: 1.4833 - val_accuracy: 0.5432
# Epoch 18/30
# 57/57 [==============================] - 7s 124ms/step - loss: 0.9418 - accuracy: 0.6554 - val_loss: 1.4986 - val_accuracy: 0.5233
# Epoch 19/30
# 57/57 [==============================] - 7s 124ms/step - loss: 0.9300 - accuracy: 0.6621 - val_loss: 1.7427 - val_accuracy: 0.4745
# Epoch 20/30
# 57/57 [==============================] - 7s 124ms/step - loss: 0.9410 - accuracy: 0.6764 - val_loss: 1.6368 - val_accuracy: 0.4812
# Epoch 21/30
# 57/57 [==============================] - 7s 123ms/step - loss: 0.8599 - accuracy: 0.6842 - val_loss: 1.5064 - val_accuracy: 0.5166
# Epoch 22/30
# 57/57 [==============================] - 7s 124ms/step - loss: 0.7886 - accuracy: 0.7185 - val_loss: 1.6476 - val_accuracy: 0.5388
# Epoch 23/30
# 57/57 [==============================] - 7s 124ms/step - loss: 0.7409 - accuracy: 0.7284 - val_loss: 1.6292 - val_accuracy: 0.5188
# Epoch 24/30
# 57/57 [==============================] - 7s 124ms/step - loss: 0.7172 - accuracy: 0.7412 - val_loss: 1.6874 - val_accuracy: 0.4878
# Epoch 25/30
# 57/57 [==============================] - 7s 124ms/step - loss: 0.7460 - accuracy: 0.7268 - val_loss: 1.9023 - val_accuracy: 0.5011
# Epoch 26/30
# 57/57 [==============================] - 7s 124ms/step - loss: 0.6618 - accuracy: 0.7622 - val_loss: 1.9493 - val_accuracy: 0.5211
# Epoch 27/30
# 57/57 [==============================] - 7s 123ms/step - loss: 0.6014 - accuracy: 0.7738 - val_loss: 2.0013 - val_accuracy: 0.4878
# Epoch 28/30
# 57/57 [==============================] - 7s 124ms/step - loss: 0.5822 - accuracy: 0.7837 - val_loss: 2.2148 - val_accuracy: 0.4368
# Epoch 29/30
# 57/57 [==============================] - 7s 124ms/step - loss: 0.5711 - accuracy: 0.7959 - val_loss: 1.7904 - val_accuracy: 0.5477
# Epoch 30/30
# 57/57 [==============================] - 7s 124ms/step - loss: 0.4998 - accuracy: 0.8103 - val_loss: 2.2205 - val_accuracy: 0.5033

# %% [markdown]
# ### Visualizing training results

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# #### Todo: Write your findings after the model fit, see if there is an evidence of model overfit or underfit

# %% [markdown]
# ### Write your findings here
# The error loss in the validation data set seems to have increased starting from 10th EPOC while it reduced consistently in training dataset.
#
# It appears that the model is overfitting consdering the patter of accuracy and error loss.

# %%
# Todo, after you have analysed the model fit history for presence of underfit or overfit, choose an appropriate data augumentation strategy. 
# Your code goes here
data_augument = keras.Sequential([
                             layers.experimental.preprocessing.RandomFlip(mode="horizontal_and_vertical",input_shape=(img_height,img_width,3)),
                             layers.experimental.preprocessing.RandomRotation(0.2, fill_mode='reflect'),
                             layers.experimental.preprocessing.RandomZoom(height_factor=(0.15, 0.15), width_factor=(0.15, 0.15), fill_mode='reflect')
])

# %%
# Todo, visualize how your augmentation strategy works for one instance of training image.
# Your code goes here
plt.figure(figsize=(12, 12))
for images, labels in train_ds.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(data_augument(images)[i].numpy().astype("uint8"))
        plt.title(class_names[labels[i]])
        plt.axis("off")

# %% [markdown]
# ### Todo:
# ### Create the model, compile and train the model

# %%
## You can use Dropout layer if there is an evidence of overfitting in your findings

## Your code goes here
model = Sequential([ data_augument,
                    layers.experimental.preprocessing.Rescaling(1./255, input_shape=(img_height, img_width,3))
      
])
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(Conv2D(32, (3, 3)))
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(64, (3, 3), padding='same'))
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(Conv2D(64, (3, 3)))
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(128, (3, 3), padding='same'))
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(Conv2D(128, (3, 3)))
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(512))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(num_classes))
model.add(Activation('softmax'))

# %% [markdown]
# ### Compiling the model

# %%
## Your code goes here
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
# View the summary of all layers
model.summary()
# Out:
# Model: "sequential_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential_9 (Sequential)   (None, 180, 180, 3)       0
#
#  rescaling_7 (Rescaling)     (None, 180, 180, 3)       0
#
#  activation_22 (Activation)  (None, 180, 180, 3)       0
#
#  batch_normalization_18 (Bat  (None, 180, 180, 3)      12
#  chNormalization)
#
#  conv2d_34 (Conv2D)          (None, 178, 178, 32)      896
#
#  activation_23 (Activation)  (None, 178, 178, 32)      0
#
#  batch_normalization_19 (Bat  (None, 178, 178, 32)     128
#  chNormalization)
#
#  max_pooling2d_24 (MaxPoolin  (None, 89, 89, 32)       0
#  g2D)
#
#  dropout_16 (Dropout)        (None, 89, 89, 32)        0
#
#  conv2d_35 (Conv2D)          (None, 89, 89, 64)        18496
#
#  activation_24 (Activation)  (None, 89, 89, 64)        0
#
#  batch_normalization_20 (Bat  (None, 89, 89, 64)       256
#  chNormalization)
#
#  conv2d_36 (Conv2D)          (None, 87, 87, 64)        36928
#
#  activation_25 (Activation)  (None, 87, 87, 64)        0
#
#  batch_normalization_21 (Bat  (None, 87, 87, 64)       256
#  chNormalization)
#
#  max_pooling2d_25 (MaxPoolin  (None, 43, 43, 64)       0
#  g2D)
#
#  dropout_17 (Dropout)        (None, 43, 43, 64)        0
#
#  conv2d_37 (Conv2D)          (None, 43, 43, 128)       73856
#
#  activation_26 (Activation)  (None, 43, 43, 128)       0
#
#  batch_normalization_22 (Bat  (None, 43, 43, 128)      512
#  chNormalization)
#
#  conv2d_38 (Conv2D)          (None, 41, 41, 128)       147584
#
#  activation_27 (Activation)  (None, 41, 41, 128)       0
#
#  batch_normalization_23 (Bat  (None, 41, 41, 128)      512
#  chNormalization)
#
#  max_pooling2d_26 (MaxPoolin  (None, 20, 20, 128)      0
#  g2D)
#
#  dropout_18 (Dropout)        (None, 20, 20, 128)       0
#
#  flatten_7 (Flatten)         (None, 51200)             0
#
#  dense_7 (Dense)             (None, 512)               26214912
#
#  activation_28 (Activation)  (None, 512)               0
#
#  dropout_19 (Dropout)        (None, 512)               0
#
#  dense_8 (Dense)             (None, 9)                 4617
#
#  activation_29 (Activation)  (None, 9)                 0
#
# =================================================================
# Total params: 26,498,965
# Trainable params: 26,498,127
# Non-trainable params: 838
# _________________________________________________________________

# %% [markdown]
# ### Training the model

# %%
## Your code goes here, note: train your model for 20 epochs
epochs = 30
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/30
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:1082: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a sigmoid or softmax activation and thus does not represent logits. Was this intended?"
#   return dispatch_target(*args, **kwargs)
# 57/57 [==============================] - 13s 189ms/step - loss: 25.9539 - accuracy: 0.2804 - val_loss: 10.1964 - val_accuracy: 0.1552
# Epoch 2/30
# 57/57 [==============================] - 11s 184ms/step - loss: 6.4588 - accuracy: 0.2998 - val_loss: 41.4144 - val_accuracy: 0.1552
# Epoch 3/30
# 57/57 [==============================] - 10s 184ms/step - loss: 3.2365 - accuracy: 0.3108 - val_loss: 65.1781 - val_accuracy: 0.1552
# Epoch 4/30
# 57/57 [==============================] - 10s 183ms/step - loss: 2.1191 - accuracy: 0.3413 - val_loss: 25.2735 - val_accuracy: 0.1552
# Epoch 5/30
# 57/57 [==============================] - 10s 183ms/step - loss: 1.9776 - accuracy: 0.3689 - val_loss: 37.4833 - val_accuracy: 0.1885
# Epoch 6/30
# 57/57 [==============================] - 10s 183ms/step - loss: 1.9795 - accuracy: 0.3684 - val_loss: 42.4779 - val_accuracy: 0.2151
# Epoch 7/30
# 57/57 [==============================] - 10s 183ms/step - loss: 1.9833 - accuracy: 0.3612 - val_loss: 22.4391 - val_accuracy: 0.2749
# Epoch 8/30
# 57/57 [==============================] - 10s 183ms/step - loss: 1.8398 - accuracy: 0.3789 - val_loss: 7.1886 - val_accuracy: 0.3126
# Epoch 9/30
# 57/57 [==============================] - 10s 184ms/step - loss: 1.7982 - accuracy: 0.3556 - val_loss: 4.8329 - val_accuracy: 0.3525
# Epoch 10/30
# 57/57 [==============================] - 10s 183ms/step - loss: 1.7411 - accuracy: 0.3960 - val_loss: 14.9799 - val_accuracy: 0.3592
# Epoch 11/30
# 57/57 [==============================] - 10s 183ms/step - loss: 1.7411 - accuracy: 0.3916 - val_loss: 6.0874 - val_accuracy: 0.3038
# Epoch 12/30
# 57/57 [==============================] - 10s 183ms/step - loss: 1.7844 - accuracy: 0.3816 - val_loss: 2.4140 - val_accuracy: 0.3747
# Epoch 13/30
# 57/57 [==============================] - 11s 184ms/step - loss: 1.7379 - accuracy: 0.3838 - val_loss: 3.4819 - val_accuracy: 0.4124
# Epoch 14/30
# 57/57 [==============================] - 10s 183ms/step - loss: 1.6252 - accuracy: 0.4298 - val_loss: 1.8156 - val_accuracy: 0.4368
# Epoch 15/30
# 57/57 [==============================] - 11s 184ms/step - loss: 1.6622 - accuracy: 0.3999 - val_loss: 5.9620 - val_accuracy: 0.4723
# Epoch 16/30
# 57/57 [==============================] - 10s 184ms/step - loss: 1.6741 - accuracy: 0.4098 - val_loss: 12.5660 - val_accuracy: 0.3614
# Epoch 17/30
# 57/57 [==============================] - 10s 183ms/step - loss: 1.7162 - accuracy: 0.4237 - val_loss: 2.6966 - val_accuracy: 0.4169
# Epoch 18/30
# 57/57 [==============================] - 11s 184ms/step - loss: 1.6724 - accuracy: 0.4187 - val_loss: 5.1355 - val_accuracy: 0.3481
# Epoch 19/30
# 57/57 [==============================] - 10s 183ms/step - loss: 1.6637 - accuracy: 0.4353 - val_loss: 2.6595 - val_accuracy: 0.4080
# Epoch 20/30
# 57/57 [==============================] - 10s 183ms/step - loss: 1.6063 - accuracy: 0.4397 - val_loss: 4.1503 - val_accuracy: 0.3902
# Epoch 21/30
# 57/57 [==============================] - 10s 183ms/step - loss: 1.6204 - accuracy: 0.4242 - val_loss: 2.0762 - val_accuracy: 0.4457
# Epoch 22/30
# 57/57 [==============================] - 10s 184ms/step - loss: 1.5848 - accuracy: 0.4491 - val_loss: 1.8984 - val_accuracy: 0.4035
# Epoch 23/30
# 57/57 [==============================] - 11s 184ms/step - loss: 1.5885 - accuracy: 0.4342 - val_loss: 1.8486 - val_accuracy: 0.4834
# Epoch 24/30
# 57/57 [==============================] - 10s 184ms/step - loss: 1.5706 - accuracy: 0.4552 - val_loss: 3.3531 - val_accuracy: 0.3880
# Epoch 25/30
# 57/57 [==============================] - 10s 182ms/step - loss: 1.6385 - accuracy: 0.4303 - val_loss: 2.4372 - val_accuracy: 0.4501
# Epoch 26/30
# 57/57 [==============================] - 10s 183ms/step - loss: 1.7436 - accuracy: 0.4231 - val_loss: 7.2386 - val_accuracy: 0.4457
# Epoch 27/30
# 57/57 [==============================] - 10s 184ms/step - loss: 1.6511 - accuracy: 0.4353 - val_loss: 2.0650 - val_accuracy: 0.3991
# Epoch 28/30
# 57/57 [==============================] - 10s 183ms/step - loss: 1.5146 - accuracy: 0.4618 - val_loss: 2.1997 - val_accuracy: 0.4612
# Epoch 29/30
# 57/57 [==============================] - 10s 183ms/step - loss: 1.5546 - accuracy: 0.4508 - val_loss: 2.2399 - val_accuracy: 0.4368
# Epoch 30/30
# 57/57 [==============================] - 10s 183ms/step - loss: 1.5861 - accuracy: 0.4508 - val_loss: 1.7752 - val_accuracy: 0.4745

# %% [markdown]
# ### Visualizing the results

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# #### Todo: Write your findings after the model fit, see if there is an evidence of model overfit or underfit. Do you think there is some improvement now as compared to the previous model run?
# Though the accuracy has gone down , but looking at the overall run, the model does seem to be overfitting now.
#  The accuracy needs to be increased further say tuning hyperparameters, adding more layer.

# %% [markdown]
# #### **Todo:** Find the distribution of classes in the training dataset.
# #### **Context:** Many times real life datasets can have class imbalance, one class can have proportionately higher number of samples compared to the others. Class imbalance can have a detrimental effect on the final model quality. Hence as a sanity check it becomes important to check what is the distribution of classes in the data.

# %%
## Your code goes here.
count=[]
for i in class_names:
    count.append(len(list(data_dir_train.glob(i+'/*.jpg'))))
plt.figure(figsize=(25,10))
plt.bar(class_names,count)
# Out:
# <BarContainer object of 9 artists>

# %% [markdown]
# #### **Todo:** Write your findings here:
# #### - numbers of samples for these 9 diseases are not uniformly distributed.
# #### - eborrheic keratosis has least number of samples
# #### - pigmented benign keratosi followed by melanoma has most.
# ### - this may be one of the factor impacting accuracy of the model.

# %% [markdown]
# #### **Todo:** Rectify the class imbalance
# #### **Context:** You can use a python package known as `Augmentor` (https://augmentor.readthedocs.io/en/master/) to add more samples across all classes so that none of the classes have very few samples.

# %%
# !pip install Augmentor
# Out:
# Requirement already satisfied: Augmentor in /usr/local/lib/python3.7/dist-packages (0.2.10)
# Requirement already satisfied: numpy>=1.11.0 in /usr/local/lib/python3.7/dist-packages (from Augmentor) (1.21.6)
# Requirement already satisfied: future>=0.16.0 in /usr/local/lib/python3.7/dist-packages (from Augmentor) (0.16.0)
# Requirement already satisfied: Pillow>=5.2.0 in /usr/local/lib/python3.7/dist-packages (from Augmentor) (7.1.2)
# Requirement already satisfied: tqdm>=4.9.0 in /usr/local/lib/python3.7/dist-packages (from Augmentor) (4.64.0)

# %% [markdown]
# To use `Augmentor`, the following general procedure is followed:
#
# 1. Instantiate a `Pipeline` object pointing to a directory containing your initial image data set.<br>
# 2. Define a number of operations to perform on this data set using your `Pipeline` object.<br>
# 3. Execute these operations by calling the `Pipeline’s` `sample()` method.

# %%
path_to_training_dataset="/content/gdrive/MyDrive/AIML/Skincancerimglib/Train/"
import Augmentor
for i in class_names:
    p = Augmentor.Pipeline("/content/gdrive/MyDrive/AIML/Skincancerimglib/Train",save_format='jpg')
    p.rotate(probability=0.7, max_left_rotation=10, max_right_rotation=10)
    p.sample(500) ## We are adding 500 samples per class to make sure that none of the classes are sparse.
# Out:
# Initialised with 2259 image(s) found.
# Output directory set to /content/gdrive/MyDrive/AIML/Skincancerimglib/Train/output.
# Processing <PIL.Image.Image image mode=RGB size=1504x1129 at 0x7FBBC67D2BD0>: 100%|██████████| 500/500 [00:48<00:00, 10.26 Samples/s]
# Initialised with 2259 image(s) found.
# Output directory set to /content/gdrive/MyDrive/AIML/Skincancerimglib/Train/output.
# Processing <PIL.Image.Image image mode=RGB size=767x576 at 0x7FBBC65F3810>: 100%|██████████| 500/500 [00:43<00:00, 11.42 Samples/s]
# Initialised with 2259 image(s) found.
# Output directory set to /content/gdrive/MyDrive/AIML/Skincancerimglib/Train/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7FBBC66B9650>: 100%|██████████| 500/500 [00:44<00:00, 11.27 Samples/s]
# Initialised with 2259 image(s) found.
# Output directory set to /content/gdrive/MyDrive/AIML/Skincancerimglib/Train/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7FBBC6709D90>: 100%|██████████| 500/500 [00:40<00:00, 12.45 Samples/s]
# Initialised with 2259 image(s) found.
# Output directory set to /content/gdrive/MyDrive/AIML/Skincancerimglib/Train/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7FBBC674D390>: 100%|██████████| 500/500 [00:36<00:00, 13.56 Samples/s]
# Initialised with 2259 image(s) found.
# Output directory set to /content/gdrive/MyDrive/AIML/Skincancerimglib/Train/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7FBC303FBD50>: 100%|██████████| 500/500 [00:52<00:00,  9.56 Samples/s]
# Initialised with 2259 image(s) found.
# Output directory set to /content/gdrive/MyDrive/AIML/Skincancerimglib/Train/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7FBC3047DC90>: 100%|██████████| 500/500 [00:46<00:00, 10.68 Samples/s]
# Initialised with 2259 image(s) found.
# Output directory set to /content/gdrive/MyDrive/AIML/Skincancerimglib/Train/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7FBBC6636990>: 100%|██████████| 500/500 [00:41<00:00, 12.02 Samples/s]
# Initialised with 2259 image(s) found.
# Output directory set to /content/gdrive/MyDrive/AIML/Skincancerimglib/Train/output.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x450 at 0x7FBC303FC2D0>: 100%|██████████| 500/500 [00:42<00:00, 11.70 Samples/s]

# %% [markdown]
# Augmentor has stored the augmented images in the output sub-directory of each of the sub-directories of skin cancer types.. Lets take a look at total count of augmented images.

# %%
data_dir_train1 = pathlib.Path("/content/gdrive/MyDrive/AIML/Skincancerimglib/Train/output/")
image_count_train1 = len(list(data_dir_train1.glob('*/*.jpg')))
print(image_count_train1)
# Out:
# 4500

# %%
##
path_list=[]
lesion_list=[]
for i in class_names:
      
    for j in data_dir_train1.glob(i+'/*.jpg'):
        path_list.append(str(j))
        lesion_list.append(i)
dataframe_dict_original = dict(zip(path_list, lesion_list))
new_df = pd.DataFrame(list(dataframe_dict_original.items()),columns = ['Path','Label'])
new_df
# Out:
#                                                    Path              Label
# 0     /content/gdrive/MyDrive/AIML/Skincancerimglib/...  actinic keratosis
# 1     /content/gdrive/MyDrive/AIML/Skincancerimglib/...  actinic keratosis
# 2     /content/gdrive/MyDrive/AIML/Skincancerimglib/...  actinic keratosis
# 3     /content/gdrive/MyDrive/AIML/Skincancerimglib/...  actinic keratosis
# 4     /content/gdrive/MyDrive/AIML/Skincancerimglib/...  actinic keratosis
# ...                                                 ...                ...
# 4495  /content/gdrive/MyDrive/AIML/Skincancerimglib/...    vascular lesion
# 4496  /content/gdrive/MyDrive/AIML/Skincancerimglib/...    vascular lesion
# 4497  /content/gdrive/MyDrive/AIML/Skincancerimglib/...    vascular lesion
# 4498  /content/gdrive/MyDrive/AIML/Skincancerimglib/...    vascular lesion
# 4499  /content/gdrive/MyDrive/AIML/Skincancerimglib/...    vascular lesion
#
# [4500 rows x 2 columns]

# %% [markdown]
# ### Lets see the distribution of augmented data after adding new images to the original training data.

# %%
new_df['Label'].value_counts()
# Out:
# melanoma                      929
# pigmented benign keratosis    923
# nevus                         757
# basal cell carcinoma          699
# squamous cell carcinoma       335
# vascular lesion               270
# actinic keratosis             243
# dermatofibroma                191
# seborrheic keratosis          153
# Name: Label, dtype: int64

# %% [markdown]
# So, now we have added 500 images to all the classes to maintain some class balance. We can add more images as we want to improve training process.

# %% [markdown]
# #### **Todo**: Train the model on the data created using Augmentor

# %%
batch_size = 32
img_height = 180
img_width = 180

# %% [markdown]
# #### **Todo:** Create a training dataset

# %%
data_dir_train="/content/gdrive/MyDrive/AIML/Skincancerimglib/Train/output"
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train,
  seed=123,
  validation_split = 0.2,
  subset = "training",
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 4500 files belonging to 9 classes.
# Using 3600 files for training.

# %% [markdown]
# #### **Todo:** Create a validation dataset

# %%
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train,
  seed=123,
  validation_split = 0.2,
  subset = "validation",
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 4500 files belonging to 9 classes.
# Using 900 files for validation.

# %% [markdown]
# #### **Todo:** Create your model (make sure to include normalization)

# %%
## your code goes here

from keras.layers import MaxPool2D
model = Sequential([
                    layers.experimental.preprocessing.Rescaling(1./255, input_shape=(img_height, img_width,3))
])
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(Conv2D(32, (3, 3)))
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(64, (3, 3), padding='same'))
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(Conv2D(64, (3, 3)))
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(128, (3, 3), padding='same'))
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(Conv2D(128, (3, 3)))
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(512))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(num_classes))
model.add(Activation('softmax'))

# %% [markdown]
# #### **Todo:** Compile your model (Choose optimizer and loss function appropriately)

# %%
## your code goes here
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %% [markdown]
# #### **Todo:**  Train your model

# %%
epochs = 30
## Your code goes here, use 50 epochs.
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/30
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:1082: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a sigmoid or softmax activation and thus does not represent logits. Was this intended?"
#   return dispatch_target(*args, **kwargs)
# 113/113 [==============================] - 23s 185ms/step - loss: 15.9976 - accuracy: 0.2861 - val_loss: 74.9163 - val_accuracy: 0.2022
# Epoch 2/30
# 113/113 [==============================] - 21s 178ms/step - loss: 2.7274 - accuracy: 0.3283 - val_loss: 18.2365 - val_accuracy: 0.1389
# Epoch 3/30
# 113/113 [==============================] - 21s 176ms/step - loss: 1.8816 - accuracy: 0.3744 - val_loss: 17.0870 - val_accuracy: 0.2189
# Epoch 4/30
# 113/113 [==============================] - 21s 174ms/step - loss: 1.7255 - accuracy: 0.3947 - val_loss: 2.7271 - val_accuracy: 0.4089
# Epoch 5/30
# 113/113 [==============================] - 21s 175ms/step - loss: 1.6669 - accuracy: 0.4036 - val_loss: 1.8821 - val_accuracy: 0.5000
# Epoch 6/30
# 113/113 [==============================] - 21s 176ms/step - loss: 1.5580 - accuracy: 0.4322 - val_loss: 9.3463 - val_accuracy: 0.4289
# Epoch 7/30
# 113/113 [==============================] - 21s 175ms/step - loss: 1.5492 - accuracy: 0.4356 - val_loss: 3.3596 - val_accuracy: 0.4156
# Epoch 8/30
# 113/113 [==============================] - 21s 176ms/step - loss: 1.5382 - accuracy: 0.4483 - val_loss: 4.6569 - val_accuracy: 0.4722
# Epoch 9/30
# 113/113 [==============================] - 22s 186ms/step - loss: 1.5222 - accuracy: 0.4583 - val_loss: 1.4782 - val_accuracy: 0.5356
# Epoch 10/30
# 113/113 [==============================] - 22s 183ms/step - loss: 1.4600 - accuracy: 0.4714 - val_loss: 1.3315 - val_accuracy: 0.5267
# Epoch 11/30
# 113/113 [==============================] - 22s 183ms/step - loss: 1.4614 - accuracy: 0.4781 - val_loss: 1.3412 - val_accuracy: 0.5444
# Epoch 12/30
# 113/113 [==============================] - 22s 187ms/step - loss: 1.3658 - accuracy: 0.5014 - val_loss: 1.2399 - val_accuracy: 0.5756
# Epoch 13/30
# 113/113 [==============================] - 22s 187ms/step - loss: 1.3254 - accuracy: 0.5158 - val_loss: 1.1546 - val_accuracy: 0.5922
# Epoch 14/30
# 113/113 [==============================] - 22s 187ms/step - loss: 1.3049 - accuracy: 0.5217 - val_loss: 3.0909 - val_accuracy: 0.5333
# Epoch 15/30
# 113/113 [==============================] - 22s 188ms/step - loss: 1.3123 - accuracy: 0.5194 - val_loss: 1.2495 - val_accuracy: 0.5600
# Epoch 16/30
# 113/113 [==============================] - 22s 184ms/step - loss: 1.2360 - accuracy: 0.5456 - val_loss: 1.1859 - val_accuracy: 0.6178
# Epoch 17/30
# 113/113 [==============================] - 21s 181ms/step - loss: 1.3321 - accuracy: 0.5386 - val_loss: 1.4098 - val_accuracy: 0.5989
# Epoch 18/30
# 113/113 [==============================] - 22s 186ms/step - loss: 1.2426 - accuracy: 0.5436 - val_loss: 1.1215 - val_accuracy: 0.6100
# Epoch 19/30
# 113/113 [==============================] - 22s 187ms/step - loss: 1.2035 - accuracy: 0.5619 - val_loss: 1.0352 - val_accuracy: 0.6156
# Epoch 20/30
# 113/113 [==============================] - 22s 185ms/step - loss: 1.1658 - accuracy: 0.5706 - val_loss: 1.2174 - val_accuracy: 0.6100
# Epoch 21/30
# 113/113 [==============================] - 22s 189ms/step - loss: 1.2794 - accuracy: 0.5478 - val_loss: 1.1059 - val_accuracy: 0.6244
# Epoch 22/30
# 113/113 [==============================] - 22s 186ms/step - loss: 1.1258 - accuracy: 0.5814 - val_loss: 1.0413 - val_accuracy: 0.6300
# Epoch 23/30
# 113/113 [==============================] - 22s 185ms/step - loss: 1.1015 - accuracy: 0.5728 - val_loss: 1.0028 - val_accuracy: 0.6489
# Epoch 24/30
# 113/113 [==============================] - 22s 186ms/step - loss: 1.0695 - accuracy: 0.5958 - val_loss: 1.1583 - val_accuracy: 0.6456
# Epoch 25/30
# 113/113 [==============================] - 22s 184ms/step - loss: 1.0582 - accuracy: 0.6017 - val_loss: 1.1227 - val_accuracy: 0.6300
# Epoch 26/30
# 113/113 [==============================] - 22s 185ms/step - loss: 1.0601 - accuracy: 0.6089 - val_loss: 1.5648 - val_accuracy: 0.6167
# Epoch 27/30
# 113/113 [==============================] - 22s 188ms/step - loss: 1.0705 - accuracy: 0.6153 - val_loss: 0.9126 - val_accuracy: 0.6967
# Epoch 28/30
# 113/113 [==============================] - 22s 183ms/step - loss: 0.9598 - accuracy: 0.6361 - val_loss: 1.1970 - val_accuracy: 0.6722
# Epoch 29/30
# 113/113 [==============================] - 22s 183ms/step - loss: 0.9901 - accuracy: 0.6250 - val_loss: 1.0420 - val_accuracy: 0.6900
# Epoch 30/30
# 113/113 [==============================] - 22s 185ms/step - loss: 0.9290 - accuracy: 0.6514 - val_loss: 1.3446 - val_accuracy: 0.6622

# %% [markdown]
# #### **Todo:**  Visualize the model results

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# #### **Todo:**  Analyze your results here. Did you get rid of underfitting/overfitting? Did class rebalance help?

# %%
#### The accuracy improved and and the loss function dropped as well. The model also don't seem to overfit.
